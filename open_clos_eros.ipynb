# %% [markdown]
# <a href="https://colab.research.google.com/github/YounkoA/Python-Nootbook/blob/main/open_clos_eros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-025043e3-a8fd-463c-b5e6-1f1b6215c98a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-025043e3-a8fd-463c-b5e6-1f1b6215c98a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wallpapertip_grey-tree-wallpaper_953498.jpg to wallpapertip_grey-tree-wallpaper_953498.jpg

# %%
import cv2
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

img = cv2.imread('wallpapertip_grey-tree-wallpaper_953498.jpg')
plt.imshow(img)

# %% [markdown]
# Erosion:

# %%
kernel = np.ones((3,3),np.uint8)
erosion = cv2.erode(img,kernel,iterations = 1)
plt.imshow(erosion)

# %% [markdown]
# Dilation:

# %%
kernel = np.ones((6,6), np.uint8)
dilation = cv2.dilate(img, kernel, iterations = 1)
plt.imshow(dilation)

# %% [markdown]
# Opening:

# %%
kernel = np.ones((4,4), np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
plt.imshow(opening)

# %% [markdown]
# Closing:

# %%
kernel = np.ones((4,4), np.uint8)
closing = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel)
plt.imshow(closing)

# %% [markdown]
# ## Morphological Gradient:

# %%
kernel = np.ones((2,2), np.uint8)
gradient = cv2.morphologyEx(dilation, cv2.MORPH_GRADIENT, kernel)
plt.imshow(gradient)

# %%
#tophat
kernel = np.ones((5,5), np.uint8)
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)
plt.imshow(tophat)

# %%
#balckhat
kernel = np.ones((4,4), np.uint8)
blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)
plt.imshow(blackhat)
