# %% [markdown]
# <a href="https://colab.research.google.com/github/YounkoA/Python-Nootbook/blob/main/lebelingimg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dabe9f7a-cd1c-46bd-a18b-613f56f5a624" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dabe9f7a-cd1c-46bd-a18b-613f56f5a624">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 111.jpg to 111.jpg

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('111.jpg')
mask = np.zeros(img.shape[:2], np.uint8)
plt.imshow(img)

# %%
bgModel = np.zeros((1, 65), np.float64)
fgModel = np.zeros((1, 65), np.float64)

rect = (166,154,617,434)
cv2.grabCut(img, mask, rect, bgModel, fgModel, 5, cv2.GC_INIT_WITH_RECT)

mask2 = np.where((mask == 2) | (mask == 0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]

plt.imshow(img), plt.colorbar(), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f4122d16b90>,
# ...
#  None)

# %%
bgModel = np.zeros((1, 65), np.float64)
fgModel = np.zeros((1, 65), np.float64)

rect = (166,154,617,434)
cv2.grabCut(img, mask, rect, bgModel, fgModel, 10, cv2.GC_INIT_WITH_RECT)

mask2 = np.where((mask == 2) | (mask == 0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]

plt.imshow(img), plt.colorbar(), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f4122d0fb10>,
# ...
#  None)
